# %% [markdown]
# <h1>Activity 1 - PALMER PENGUIN DATA ANALYTICS PROJECT</h1>
# <hr>
# <h3> Data Analyst: Emmanuel M. Aviles</h3>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Converting Dataset(s) into Dataframe</h2>
# <h2>Requirements</h2>
# <ul>
#     <li>Name of the Dataframes</li>
#     <li>Filepath</li>
# </ul>

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h3>Descriptive Analysis</h3>

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
penguins.isnull
# Out:
# <bound method DataFrame.isnull of      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341     True
# 342     True
# 343    False
# Name: sex, Length: 344, dtype: bool

# %% [markdown]
# <h3>Adelie Dataframe</h3>

# %%
adelie_df = penguins[penguins['species']== 'Adelie']
adelie_df
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 147    148  Adelie      Dream            36.6           18.4
# 148    149  Adelie      Dream            36.0           17.8
# 149    150  Adelie      Dream            37.8           18.1
# 150    151  Adelie      Dream            36.0           17.1
# 151    152  Adelie      Dream            41.5           18.5
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %% [markdown]
# <h3>Gentoo Dataframe</h3>

# %%
Gentoo_df = penguins[penguins['species']== 'Gentoo']
Gentoo_df
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe            46.1           13.2              211.0
# 153    154  Gentoo  Biscoe            50.0           16.3              230.0
# 154    155  Gentoo  Biscoe            48.7           14.1              210.0
# 155    156  Gentoo  Biscoe            50.0           15.2              218.0
# 156    157  Gentoo  Biscoe            47.6           14.5              215.0
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe             NaN            NaN                NaN
# 272    273  Gentoo  Biscoe            46.8           14.3              215.0
# 273    274  Gentoo  Biscoe            50.4           15.7              222.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
# 275    276  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h3>Chinstrap Dataframe</h3>

# %%
Chinstrap_df = penguins[penguins['species']== 'Chinstrap'] 
Chinstrap_df
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
penguins[(penguins['species']== 'Chinstrap') & (penguins['body_mass_g'] >= 4000)]
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 284    285  Chinstrap  Dream            46.0           18.9
# 289    290  Chinstrap  Dream            52.0           18.1
# 291    292  Chinstrap  Dream            50.5           19.6
# 295    296  Chinstrap  Dream            49.2           18.2
# 301    302  Chinstrap  Dream            52.0           19.0
# 305    306  Chinstrap  Dream            52.8           20.0
# 307    308  Chinstrap  Dream            54.2           20.8
# 309    310  Chinstrap  Dream            51.0           18.8
# 313    314  Chinstrap  Dream            52.0           20.7
# 315    316  Chinstrap  Dream            53.5           19.9
# 321    322  Chinstrap  Dream            50.8           18.5
# 323    324  Chinstrap  Dream            49.0           19.6
# 329    330  Chinstrap  Dream            50.7           19.7
# 333    334  Chinstrap  Dream            49.3           19.9
# 339    340  Chinstrap  Dream            55.8           19.8
# ...

# %% [markdown]
# <h2>FILLING UP NULL VALUES</h2>

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h2>CHANGING DATA TYPES</h2>

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year
# 0           181.000000  3750.000000    male  2007
# 1           186.000000  3800.000000  female  2007
# ...

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['year'] = penguins['year'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')
penguins['island'] = penguins['island'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
# dtypes: category(4), float64(4), int64(1)
# memory usage: 15.4 KB

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 1000 , 1)

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  mass_kg
# 0           181.000000  3750.000000    male  2007      3.8
# 1           186.000000  3800.000000  female  2007      3.8
# ...

# %%
penguins.columns
# Out:
# Index(['rowid', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year', 'mass_kg'],
#       dtype='object')

# %%
penguins['mass_kg'].min()
# Out:
# np.float64(2.7)

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
penguins[penguins['mass_kg'] == 2.7]
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 314    315  Chinstrap  Dream            46.9           16.6
#
#      flipper_length_mm  body_mass_g     sex  year  mass_kg
# 314              192.0       2700.0  female  2008      2.7

# %%
penguins[penguins['mass_kg'] == 6.3]
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169    170  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex  year  mass_kg
# 169       6300.0  male  2007      6.3

# %%
penguins['mass_kg'].mean()
# Out:
# np.float64(4.2020348837209305)

# %%
penguins[penguins['mass_kg'] == 4]
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 23      24     Adelie     Biscoe            38.2           18.1
# 29      30     Adelie     Biscoe            40.5           18.9
# 36      37     Adelie      Dream            38.8           20.0
# 53      54     Adelie     Biscoe            42.0           19.5
# 63      64     Adelie     Biscoe            41.1           18.2
# 65      66     Adelie     Biscoe            41.6           18.0
# 79      80     Adelie  Torgersen            42.1           19.1
# 88      89     Adelie      Dream            38.3           19.2
# 125    126     Adelie  Torgersen            40.6           19.0
# 129    130     Adelie  Torgersen            44.1           18.0
# 137    138     Adelie      Dream            40.2           20.1
# 151    152     Adelie      Dream            41.5           18.5
# 192    193     Gentoo     Biscoe            42.7           13.7
# 281    282  Chinstrap      Dream            45.2           17.8
# ...

# %%
special_island = penguins.groupby(['species', 'island', 'sex']).size()

# %%
special_island
# Out:
# species    island     sex
# Adelie     Biscoe     female    22
#                       male      22
#            Dream      female    27
#                       male      29
#            Torgersen  female    24
#                       male      28
# Chinstrap  Biscoe     female     0
#                       male       0
#            Dream      female    34
#                       male      34
#            Torgersen  female     0
#                       male       0
# Gentoo     Biscoe     female    58
#                       male      66
#            Dream      female     0
#                       male       0
#            Torgersen  female     0
#                       male       0
# dtype: int64

# %%
special_island = penguins.groupby(['species', 'island', 'sex'])['mass_kg'].mean()
special_island
# Out:
# species    island     sex
# Adelie     Biscoe     female    3.372727
#                       male      4.059091
#            Dream      female    3.344444
#                       male      4.013793
#            Torgersen  female    3.387500
#                       male      3.989286
# Chinstrap  Biscoe     female         NaN
#                       male           NaN
#            Dream      female    3.523529
#                       male      3.938235
#            Torgersen  female         NaN
#                       male           NaN
# Gentoo     Biscoe     female    4.681034
#                       male      5.410606
#            Dream      female         NaN
#                       male           NaN
#            Torgersen  female         NaN
#                       male           NaN
# Name: mass_kg, dtype: float64

# %% [markdown]
# <h1>CORRELATION ANALYSIS</h1>
# <hr>
# <h3>Testing Correlation using Pearson R</h3>
# <hr>
# <h4>Pearson R can test correlation between two Variables, given that both Variables are Numerical Data</h4>

# %%
flipper_mass = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])
flipper_mass
# Out:
# np.float64(0.8712017673060114)

# %%
bill_mass = penguins['body_mass_g'].corr(penguins['bill_length_mm'])
bill_mass
# Out:
# np.float64(0.5951098244376303)

# %% [markdown]
# <h1> Numerical to Categorical</h1>

# %%
from scipy.stats import f_oneway
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from scipy.stats import f_oneway
#
# ModuleNotFoundError: No module named 'scipy'

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']

# %%
stats, correlation = f_oneway(penguins[penguins['sex'] == 'female']['body_mass_g'],penguins[penguins['sex'] == 'male']['body_mass_g'])
correlation

# %% [markdown]
# <h1> 13 Question and Insights </h1>

# %% [markdown]
# <h2>1. Which specie have the most penguin count in the data?</h2>
#
# <hr>

# %%
penguins['species'].value_counts()

# %% [markdown]
# <h4> Insight: Base on the data Adelie has the most head count among the 3.</h4>
#
# <hr>

# %% [markdown]
# <h2> 2. Did the average body mass of penguins changed across the years?</h2>
#
# <hr>

# %%
penguins.groupby('year')['body_mass_g'].mean()

# %% [markdown]
# <h4>Insight: There may be slight changes in body mass of the penguins between years (2007–2009) maybe its because of food supply that year.</h4>
#
# <hr>

# %% [markdown]
# <h2>3. How many penguins of each species live on each island?</h2>
#
# <hr>

# %%
penguin_count = penguins.groupby(['species', 'island']).size()
penguin_count

# %% [markdown]
# <h4>Insight: Base on the result Adelie was scattered to different island they are a traveler, Chinstrap only reside on Dream Island and the Gentoo only reside on Biscoe island</h4>
#
# <hr

# %% [markdown]
# <h2>4. What is the lightest weight of penguin in this data? </h2>
#
# <hr>

# %%
penguins['mass_kg'].min()

# %%
penguins[penguins['mass_kg'] == 2.7]

# %% [markdown]
# <h4>Insight: From the data result it shows that the lightest penguin is a female that weigh 2.7 kg and its other information supports the data.</h4>
# <hr>

# %% [markdown]
# <h2>5. Which gender has the more number? is it female or male? </h2>
#
# <hr>

# %%
sex = penguins['sex'].value_counts()
sex

# %% [markdown]
# <h4>Insight: Base on the result the male has a better number than the female penguins.</h4>
#
# <hr>

# %% [markdown]
# <h2>6. What is the average flipper length for each species?
# <hr>

# %%
penguins.groupby('species')['flipper_length_mm'].mean()

# %% [markdown]
# <h4>Insights: From the result Gentoo had the longest flipper span and the second one is the chinstrap and the one who had the shortest among the 3 was the adelie but base in on other question adelie has the most number means more productive.</h4>
#
# <hr>

# %% [markdown]
# <h2>7. What is the heaviest female penguin?</h2>
#
# <hr>

# %%
females = penguins[(penguins['sex'] == 'female') & (penguins['body_mass_g'].notna())]
max_mass = females['body_mass_g'].max()
heaviest = females[females['body_mass_g'] == max_mass]

heaviest

# %% [markdown]
# <h4>Insights: In the result it says that there are 2 heaviest female it weigh 5.2kg they are from the same specie but different year but it only means gentoo female are heavier than other female specie.</h4>
#
# <hr>

# %% [markdown]
# <h2>8. Is there any connection, if heavier weight to the length of the flippers?</h2>
#
# <hr>

# %%
flipper_mass = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])
flipper_mass

# %% [markdown]
# <h4>Insigth: Yes there is, the heavier the penguin the longer the its flippers because its higher then 0.5.</h4>

# %% [markdown]
# ---

# %% [markdown]
# <h2>9. Does weight affects the bill depth?</h2>

# %%
bill_depth = penguins['body_mass_g'].corr(penguins['bill_depth_mm'])
bill_depth
# Out:
# np.float64(-0.4719156211860664)

# %% [markdown]
# <h4>Insight: No, there is no correlation between the two because it is below 0.5</h4>

# %% [markdown]
# <h2>10. How many female penguins have a body mass greater than or equal to 5000g?</h2>

# %%
females_kg = penguins[(penguins['sex'] == 'female') & (penguins['mass_kg'] >= 5)]

# %%
females_kg.value_counts().sum()
females_kg
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 173    174  Gentoo  Biscoe            45.1           14.5              215.0
# 176    177  Gentoo  Biscoe            42.9           13.1              215.0
# 184    185  Gentoo  Biscoe            45.1           14.5              207.0
# 186    187  Gentoo  Biscoe            49.1           14.8              220.0
# 188    189  Gentoo  Biscoe            42.6           13.7              213.0
# 200    201  Gentoo  Biscoe            44.9           13.3              213.0
# 225    226  Gentoo  Biscoe            46.5           14.8              217.0
# 242    243  Gentoo  Biscoe            47.5           15.0              218.0
# 254    255  Gentoo  Biscoe            47.2           15.5              215.0
# 262    263  Gentoo  Biscoe            50.5           15.2              216.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex  year  mass_kg
# ...

# %% [markdown]
# <h4> Insight : Base on the result 8 Gentoo female dominated the result of 5kg or above, we can say that female Gentoo specie was the heaviest among the 3.</h4>

# %% [markdown]
# <h2>11. How many Chinstrap penguins have a bill length below 50 mm?</h2>

# %%
chinstrap_bill = penguins[(penguins['species'] == 'Chinstrap') & (penguins['bill_length_mm'] <= 50)]

# %%
chinstrap_bill.value_counts().sum()
# Out:
# np.int64(38)

# %% [markdown]
# <h4>Insight: There are 38 Chinstrap penguins with bill lengths shorter than 50 mm. This means their bill length can vary by the specie.</h4>

# %% [markdown]
# <h2>12. Which species had the lowest average body mass (kg) in 2007?</h2>

# %%
lowest_penguin = penguins[penguins['year'] == 2007]
lowest_penguin['mass_kg'].min()
# Out:
# np.float64(2.9)

# %%
mass = penguins[penguins['mass_kg'] == 2.9]
mass
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 54      55     Adelie     Biscoe            34.5           18.1
# 98      99     Adelie      Dream            33.1           16.1
# 104    105     Adelie     Biscoe            37.9           18.6
# 116    117     Adelie  Torgersen            38.6           17.0
# 298    299  Chinstrap      Dream            43.2           16.6
#
#      flipper_length_mm  body_mass_g     sex  year  mass_kg
# 54               187.0       2900.0  female  2008      2.9
# 98               178.0       2900.0  female  2008      2.9
# 104              193.0       2925.0  female  2009      2.9
# 116              188.0       2900.0  female  2009      2.9
# 298              187.0       2900.0  female  2007      2.9

# %% [markdown]
# <h4>Insight: In this result the adelie showed more result than the other specie and the other specie that has the lowest average body was from the chinstrap base on this we can say that adelie are the lightest specie among the 3.</h4>

# %% [markdown]
# <h2>13. Does weight affects the bill length?</h2>

# %%
bill_length = penguins['body_mass_g'].corr(penguins['bill_length_mm'])
bill_length
# Out:
# np.float64(0.5951098244376303)

# %% [markdown]
# <h4>Insight: From the result it shows that, Yes weight affects the bill length of the penguin  </h4>
